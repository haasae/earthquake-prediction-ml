# %% [markdown]
# # Quickstart Notebook\nThis is an optional notebook. The main pipeline is in `scripts/run_pipeline.py`.\n\nRun:\n```\n!python scripts/run_pipeline.py\n```\n

# %%
# !python scripts/run_pipeline.py
